# %%
import pandas as pd 
import matplotlib.pylab as plt
df=pd.read_csv("data10.csv")
df.head()
# Out:
#               Datetime    BSE.NS  CGPOWER.NS  BHARATFORG.NS  TATATECH.NS  \
# 0  2024-05-24 13:00:00  0.999981    1.001097       1.002937     1.001031
# 1  2024-05-24 13:15:00  1.005317    1.001254       1.001710     1.015417
# 2  2024-05-24 13:30:00  1.034654    1.000627       1.007454     1.026242
# 3  2024-05-24 13:45:00  1.030205    1.003682       1.008745     1.035286
# 4  2024-05-24 14:00:00  1.027697    1.011283       1.020362     1.026710
#
#    DELHIVERY.NS  PATANJALI.NS  TVSMOTOR.NS  SIEMENS.NS  HDFCBANK.NS  ...  \
# 0      1.000997      1.000598     0.996261    1.001015     0.998741  ...
# 1      1.000374      1.000844     0.999597    1.005736     1.000331  ...
# 2      1.003737      0.999296     1.000716    1.006751     1.000431  ...
# 3      1.002741      0.999261     1.005798    1.008981     1.001027  ...
# 4      1.009094      0.996446     1.006582    1.008249     1.003578  ...
#
#    ASHOKLEY.NS    BDL.NS  TATACHEM.NS  GLAND.NS   FACT.NS  MAZDOCK.NS  \
# ...

# %%
df.iloc[:,1]
# Out:
# 0    0.999981
# 1    1.005317
# 2    1.034654
# 3    1.030205
# 4    1.027697
# 5    1.026622
# 6    1.029262
# 7    1.032675
# 8    1.029922
# 9    1.028037
# Name: BSE.NS, dtype: float64

# %%
df.columns[1].replace(".NS","")
# Out:
# 'BSE'

# %%
import pandas as pd 
df=pd.read_csv('nifty_data.csv')

# %%
df.head()
df.set_index('index',inplace=True)

# %%
df.loc['ABB.NS']['Company Name']
# Out:
# 'ABB India Ltd.'

# %%
df
# Out:
#              index                        Company Name  \
# 0           ABB.NS                      ABB India Ltd.
# 1           ACC.NS                            ACC Ltd.
# 2     APLAPOLLO.NS               APL Apollo Tubes Ltd.
# 3        AUBANK.NS          AU Small Finance Bank Ltd.
# 4    ADANIENSOL.NS         Adani Energy Solutions Ltd.
# ..             ...                                 ...
# 196       WIPRO.NS                          Wipro Ltd.
# 197     YESBANK.NS                       Yes Bank Ltd.
# 198        ZEEL.NS  Zee Entertainment Enterprises Ltd.
# 199      ZOMATO.NS                         Zomato Ltd.
# 200   ZYDUSLIFE.NS             Zydus Lifesciences Ltd.
#
#                               Industry         Symbol
# 0                        Capital Goods         ABB.NS
# 1               Construction Materials         ACC.NS
# 2                        Capital Goods   APLAPOLLO.NS
# 3                   Financial Services      AUBANK.NS
# ...
